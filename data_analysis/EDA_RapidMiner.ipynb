# %% [markdown]
# # Attacks on Healthcare Systems EDA

# %% [markdown]
# - MIT Emerging Talent Project Data Analysis - Group 6
# - Most of this initial data investigation done by using **RapidMiner Tool**

# %% [markdown]
# ## Attack Date Statistics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### * Adding the weekday and year to make investigate the attacks based on the given dates

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Observation:
# - Friday has the highest frequency hospitals attacks.

# %% [markdown]
# ## Attacks Geo-location

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![pie_chart_hospital_attacks_country.svg](attachment:pie_chart_hospital_attacks_country.svg)

# %% [markdown]
# Country / Territory
#
# ![image.png](attachment:image.png)
